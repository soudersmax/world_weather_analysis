# %%
## Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from configbackup import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
## Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)
# Add the lats and lngs into a list
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
import sys
## Calling the API and Parsing JSON Data
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through alll the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    
    # create end point url
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers an d the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count 
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
        # If an error is experienced skip the city
    except:
        print("City not found, skipping...")
        print(sys.exc_info())
        pass
        
# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | deputatskiy
# {'coord': {'lon': 139.9, 'lat': 69.3}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 36.91, 'feels_like': 32.2, 'temp_min': 36.91, 'temp_max': 36.91, 'pressure': 1024, 'humidity': 89, 'sea_level': 1024, 'grnd_level': 954}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 108}, 'clouds': {'all': 90}, 'dt': 1598646770, 'sys': {'country': 'RU', 'sunrise': 1598640466, 'sunset': 1598697324}, 'timezone': 36000, 'id': 2028164, 'name': 'Deputatsky', 'cod': 200}
# Processing Record 2 of Set 1 | san policarpo
# {'coord': {'lon': 125.51, 'lat': 12.18}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.1, 'feels_like': 86.25, 'temp_min': 80.1, 'temp_max': 80.1, 'pressure': 1005, 'humidity': 84, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 7.27, 'deg': 291}, 'clouds': {'all': 100}, 'dt': 1598646770, 'sys': {'country': 'PH', 'sunrise': 1598650054, 'sunset': 1598694641}, 'timezone': 28800, 'id': 1688696, 'name': 'San Policarpo', 'cod': 200}
# Processing Record 3 of Set 1 | asau
# {'coord': {'lon': 26.4, 'lat': 46.43}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 65.48, 'feels_like': 63.5, 'temp_min': 62.01, 'temp_max': 68, 'pressure': 1013, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 70}, 'rain': {'1h': 0.21}, 'clouds': {'all': 47}, 'dt': 1598646771, 'sys': {'type': 1, 'id': 6909, 'country': 'RO', 'sunrise': 1598585397, 'sunset': 1598634097}, 'timezone': 10800, 'id': 686090, 'name': 'Asău', 'cod': 200}
# Processing Record 4 of Set 1 | jamestown
# {'coord': {'lon': -79.24, 'lat': 42.1}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.23, 'feels_like': 77.49, 'temp_min': 73.4, 'temp_max': 78.01, 'pressure': 1011, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1598646514, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1598611139, 'sunset': 1598659052}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 5 of Set 1 | airai
# {'coord': {'lon': 125.41, 'lat': -8.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 56.35, 'feels_like': 55.22, 'temp_min': 56.35, 'temp_max': 56.35, 'pressure': 1011, 'humidity': 91, 'sea_level': 1011, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 4.07, 'deg': 99}, 'clouds': {'all': 49}, 'dt': 1598646771, 'sys': {'country': 'TL', 'sunrise': 1598650922, 'sunset': 1598693821}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 6 of Set 1 | bahia blanca
# {'coord': {'lon': -62.27, 'lat': -38.72}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 64.44, 'feels_like': 58.35, 'temp_min': 64.44, 'temp_max': 64.44, 'pressure': 1011, 'humidity': 46, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 8.03, 'deg': 281}, 'clouds': {'all': 50}, 'dt': 1598646493, 'sys': {'country': 'AR', 'sunrise': 1598611010, 'sunset': 1598651036}, 'timezone': -10800, 'id': 3865086, 'name': 'Bahía Blanca', 'cod': 200}
# Processing Record 7 of Set 1 | bluff
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 35.94, 'temp_min': 45, 'temp_max': 45, 'pressure': 1008, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 194, 'gust': 21.99}, 'clouds': {'all': 83}, 'dt': 1598646753, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1598642584, 'sunset': 1598681561}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 8 of Set 1 | taoudenni
# {'coord': {'lon': -3.98, 'lat': 22.68}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 101.08, 'feels_like': 91.65, 'temp_min': 101.08, 'temp_max': 101.08, 'pressure': 1002, 'humidity': 8, 'sea_level': 1002, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 9.64, 'deg': 39}, 'clouds': {'all': 0}, 'dt': 1598646771, 'sys': {'country': 'ML', 'sunrise': 1598594250, 'sunset': 1598639823}, 'timezone': 0, 'id': 2450173, 'name': 'Taoudenni', 'cod': 200}
# Processing Record 9 of Set 1 | seoul
# {'coord': {'lon': 126.98, 'lat': 37.57}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.54, 'feels_like': 88.61, 'temp_min': 77, 'temp_max': 78.8, 'pressure': 1007, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 1.48, 'deg': 130}, 'clouds': {'all': 20}, 'dt': 1598646599, 'sys': {'type': 1, 'id': 8117, 'country': 'KR', 'sunrise': 1598648397, 'sunset': 1598695593}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}
# Processing Record 10 of Set 1 | nesna
# {'coord': {'lon': 13.02, 'lat': 66.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 47.07, 'feels_like': 43.9, 'temp_min': 44.6, 'temp_max': 50, 'pressure': 1010, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1598646772, 'sys': {'type': 1, 'id': 1641, 'country': 'NO', 'sunrise': 1598585422, 'sunset': 1598640493}, 'timezone': 7200, 'id': 3144661, 'name': 'Nesna', 'cod': 200}
# Processing Record 11 of Set 1 | albany
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.17, 'feels_like': 76.48, 'temp_min': 73, 'temp_max': 75, 'pressure': 1007, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 261, 'gust': 4}, 'clouds': {'all': 53}, 'dt': 1598646601, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1598609833, 'sunset': 1598657828}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 12 of Set 1 | rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.47, 'feels_like': 67.96, 'temp_min': 68.47, 'temp_max': 68.47, 'pressure': 1019, 'humidity': 67, 'sea_level': 1019, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 4.85, 'deg': 315}, 'clouds': {'all': 0}, 'dt': 1598646746, 'sys': {'country': 'PF', 'sunrise': 1598627622, 'sunset': 1598669313}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 13 of Set 1 | waingapu
# {'coord': {'lon': 120.26, 'lat': -9.66}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73.22, 'feels_like': 72.23, 'temp_min': 73.22, 'temp_max': 73.22, 'pressure': 1011, 'humidity': 75, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.98, 'deg': 119}, 'clouds': {'all': 0}, 'dt': 1598646772, 'sys': {'country': 'ID', 'sunrise': 1598652186, 'sunset': 1598695028}, 'timezone': 28800, 'id': 1622318, 'name': 'Waingapu', 'cod': 200}
# Processing Record 14 of Set 1 | paamiut
# {'coord': {'lon': -49.67, 'lat': 61.99}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 48.79, 'feels_like': 42.51, 'temp_min': 48.79, 'temp_max': 48.79, 'pressure': 996, 'humidity': 92, 'sea_level': 996, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 9.73, 'deg': 30}, 'rain': {'1h': 1.35}, 'clouds': {'all': 100}, 'dt': 1598646772, 'sys': {'country': 'GL', 'sunrise': 1598601543, 'sunset': 1598654457}, 'timezone': -7200, 'id': 3421193, 'name': 'Paamiut', 'cod': 200}
# Processing Record 15 of Set 1 | port alfred
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 57.67, 'feels_like': 51.98, 'temp_min': 57.67, 'temp_max': 57.67, 'pressure': 1010, 'humidity': 70, 'sea_level': 1010, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 9.28, 'deg': 337}, 'clouds': {'all': 0}, 'dt': 1598646741, 'sys': {'country': 'ZA', 'sunrise': 1598589329, 'sunset': 1598629929}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 16 of Set 1 | voh
# {'coord': {'lon': 164.7, 'lat': -20.97}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 68.4, 'feels_like': 68.67, 'temp_min': 68.4, 'temp_max': 68.4, 'pressure': 1020, 'humidity': 83, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 7.43, 'deg': 149}, 'clouds': {'all': 100}, 'dt': 1598646772, 'sys': {'country': 'NC', 'sunrise': 1598641996, 'sunset': 1598683891}, 'timezone': 39600, 'id': 2137748, 'name': 'Voh', 'cod': 200}
# Processing Record 17 of Set 1 | lebu
# {'coord': {'lon': -73.65, 'lat': -37.62}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.47, 'feels_like': 34.34, 'temp_min': 46.47, 'temp_max': 46.47, 'pressure': 1019, 'humidity': 93, 'sea_level': 1019, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 19.3, 'deg': 183}, 'clouds': {'all': 99}, 'dt': 1598646692, 'sys': {'country': 'CL', 'sunrise': 1598613671, 'sunset': 1598653837}, 'timezone': -14400, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 18 of Set 1 | tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D4576A788>)
# Processing Record 19 of Set 1 | hwange
# {'coord': {'lon': 26.5, 'lat': -18.37}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 67.23, 'feels_like': 64.11, 'temp_min': 67.23, 'temp_max': 67.23, 'pressure': 1011, 'humidity': 36, 'sea_level': 1011, 'grnd_level': 924}, 'visibility': 10000, 'wind': {'speed': 1.36, 'deg': 184}, 'clouds': {'all': 0}, 'dt': 1598646773, 'sys': {'country': 'ZW', 'sunrise': 1598588680, 'sunset': 1598630765}, 'timezone': 7200, 'id': 889942, 'name': 'Hwange', 'cod': 200}
# Processing Record 20 of Set 1 | butaritari
# {'coord': {'lon': 172.79, 'lat': 3.07}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.35, 'feels_like': 82.65, 'temp_min': 82.35, 'temp_max': 82.35, 'pressure': 1010, 'humidity': 73, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 15.61, 'deg': 143}, 'clouds': {'all': 100}, 'dt': 1598646773, 'sys': {'country': 'KI', 'sunrise': 1598639079, 'sunset': 1598682927}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 21 of Set 1 | cidreira
# {'coord': {'lon': -50.21, 'lat': -30.18}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 65.34, 'feels_like': 65.01, 'temp_min': 65.34, 'temp_max': 65.34, 'pressure': 1014, 'humidity': 80, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 5.73, 'deg': 76}, 'rain': {'1h': 2.73}, 'clouds': {'all': 55}, 'dt': 1598646773, 'sys': {'country': 'BR', 'sunrise': 1598607635, 'sunset': 1598648624}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# Processing Record 22 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 33.8, 'feels_like': 18, 'temp_min': 33.8, 'temp_max': 33.8, 'pressure': 989, 'humidity': 80}, 'visibility': 8000, 'wind': {'speed': 20.8, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1598646690, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1598613798, 'sunset': 1598651143}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 23 of Set 1 | nizhneyansk
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D4576AD48>)
# Processing Record 24 of Set 1 | payo
# {'coord': {'lon': 103.64, 'lat': -3.75}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 71.76, 'feels_like': 76.51, 'temp_min': 71.76, 'temp_max': 71.76, 'pressure': 1009, 'humidity': 83, 'sea_level': 1009, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 170}, 'clouds': {'all': 34}, 'dt': 1598646774, 'sys': {'country': 'ID', 'sunrise': 1598655940, 'sunset': 1598699250}, 'timezone': 25200, 'id': 1638775, 'name': 'Payo', 'cod': 200}
# Processing Record 25 of Set 1 | lavrentiya
# {'coord': {'lon': -171, 'lat': 65.58}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.58, 'feels_like': 45.59, 'temp_min': 48.58, 'temp_max': 48.58, 'pressure': 1014, 'humidity': 78, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.08, 'deg': 58}, 'clouds': {'all': 90}, 'dt': 1598646774, 'sys': {'country': 'RU', 'sunrise': 1598716456, 'sunset': 1598770534}, 'timezone': 43200, 'id': 4031637, 'name': 'Lavrentiya', 'cod': 200}
# Processing Record 26 of Set 1 | colac
# {'coord': {'lon': 143.58, 'lat': -38.33}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 42.66, 'feels_like': 37.27, 'temp_min': 42.01, 'temp_max': 44.01, 'pressure': 1026, 'humidity': 98}, 'visibility': 10000, 'wind': {'speed': 6.38, 'deg': 328}, 'clouds': {'all': 5}, 'dt': 1598646774, 'sys': {'type': 3, 'id': 2007878, 'country': 'AU', 'sunrise': 1598647945, 'sunset': 1598688078}, 'timezone': 36000, 'id': 2171069, 'name': 'Colac', 'cod': 200}
# Processing Record 27 of Set 1 | mount isa
# {'coord': {'lon': 139.5, 'lat': -20.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 56.46, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1019, 'humidity': 31}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 110}, 'clouds': {'all': 0}, 'dt': 1598646710, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1598648030, 'sunset': 1598689951}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# Processing Record 28 of Set 1 | skalistyy
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45783EC8>)
# Processing Record 29 of Set 1 | vila franca do campo
# {'coord': {'lon': -25.43, 'lat': 37.72}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 75.74, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1023, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 290}, 'clouds': {'all': 20}, 'dt': 1598646699, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1598598536, 'sunset': 1598645831}, 'timezone': 0, 'id': 3372472, 'name': 'Vila Franca do Campo', 'cod': 200}
# Processing Record 30 of Set 1 | kodiak
# {'coord': {'lon': -152.41, 'lat': 57.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 56.08, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1010, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 280}, 'clouds': {'all': 1}, 'dt': 1598646692, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1598627002, 'sunset': 1598678303}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 31 of Set 1 | bengkulu
# {'coord': {'lon': 102.27, 'lat': -3.8}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.51, 'feels_like': 80.06, 'temp_min': 75.51, 'temp_max': 75.51, 'pressure': 1009, 'humidity': 85, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 6.06, 'deg': 103}, 'clouds': {'all': 99}, 'dt': 1598646757, 'sys': {'country': 'ID', 'sunrise': 1598656271, 'sunset': 1598699577}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 32 of Set 1 | qaanaaq
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 40.17, 'feels_like': 33.94, 'temp_min': 40.17, 'temp_max': 40.17, 'pressure': 1018, 'humidity': 87, 'sea_level': 1018, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 6.02, 'deg': 75}, 'clouds': {'all': 100}, 'dt': 1598646753, 'sys': {'country': 'GL', 'sunrise': 1598597908, 'sunset': 1598667541}, 'timezone': -10800, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 33 of Set 1 | dikson
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 49.03, 'feels_like': 43.11, 'temp_min': 49.03, 'temp_max': 49.03, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 7.58, 'deg': 155}, 'clouds': {'all': 68}, 'dt': 1598646754, 'sys': {'country': 'RU', 'sunrise': 1598652630, 'sunset': 1598713642}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 34 of Set 1 | saldanha
# {'coord': {'lon': 17.94, 'lat': -33.01}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 48.25, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1012, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 310}, 'rain': {'1h': 0.23}, 'clouds': {'all': 49}, 'dt': 1598646692, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1598591443, 'sunset': 1598632110}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# Processing Record 35 of Set 1 | punta arenas
# {'coord': {'lon': -70.92, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 32, 'feels_like': 6.6, 'temp_min': 32, 'temp_max': 32, 'pressure': 996, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 38.03, 'deg': 260, 'gust': 51.67}, 'clouds': {'all': 40}, 'dt': 1598646558, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1598614244, 'sunset': 1598651954}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 36 of Set 1 | saint george
# {'coord': {'lon': -113.58, 'lat': 37.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 101.08, 'feels_like': 94.6, 'temp_min': 100, 'temp_max': 102, 'pressure': 1012, 'humidity': 10}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 330}, 'clouds': {'all': 1}, 'dt': 1598646600, 'sys': {'type': 1, 'id': 5832, 'country': 'US', 'sunrise': 1598619746, 'sunset': 1598666924}, 'timezone': -21600, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 37 of Set 1 | amderma
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45783EC8>)
# Processing Record 38 of Set 1 | sakakah
# {'coord': {'lon': 40.21, 'lat': 29.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 93.2, 'feels_like': 86.18, 'temp_min': 93.2, 'temp_max': 93.2, 'pressure': 1009, 'humidity': 15}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1598646775, 'sys': {'type': 1, 'id': 7431, 'country': 'SA', 'sunrise': 1598583257, 'sunset': 1598629609}, 'timezone': 10800, 'id': 102527, 'name': 'Sakakah', 'cod': 200}
# Processing Record 39 of Set 1 | yellowknife
# {'coord': {'lon': -114.35, 'lat': 62.46}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 52.95, 'feels_like': 48.65, 'temp_min': 52, 'temp_max': 53.6, 'pressure': 1014, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1598646576, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1598616995, 'sunset': 1598670044}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 40 of Set 1 | hermanus
# {'coord': {'lon': 19.23, 'lat': -34.42}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 52, 'feels_like': 48.27, 'temp_min': 52, 'temp_max': 52, 'pressure': 1010, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 328, 'gust': 10}, 'clouds': {'all': 37}, 'dt': 1598646748, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1598591213, 'sunset': 1598631722}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 41 of Set 1 | port keats
# {'coord': {'lon': 129.55, 'lat': -14.25}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.67, 'feels_like': 61.23, 'temp_min': 66.67, 'temp_max': 66.67, 'pressure': 1015, 'humidity': 55, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 9.78, 'deg': 124}, 'clouds': {'all': 0}, 'dt': 1598646775, 'sys': {'country': 'AU', 'sunrise': 1598650143, 'sunset': 1598692613}, 'timezone': 34200, 'id': 2063039, 'name': 'Port Keats', 'cod': 200}
# Processing Record 42 of Set 1 | kaeo
# {'coord': {'lon': 173.78, 'lat': -35.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 34.95, 'temp_min': 45, 'temp_max': 45, 'pressure': 1022, 'humidity': 3}, 'visibility': 10000, 'wind': {'speed': 5.37, 'deg': 344}, 'clouds': {'all': 9}, 'dt': 1598646776, 'sys': {'type': 3, 'id': 2012217, 'country': 'NZ', 'sunrise': 1598640514, 'sunset': 1598681016}, 'timezone': 43200, 'id': 2189343, 'name': 'Kaeo', 'cod': 200}
# Processing Record 43 of Set 1 | sembe
# {'coord': {'lon': 14.58, 'lat': 1.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.78, 'feels_like': 77.9, 'temp_min': 71.78, 'temp_max': 71.78, 'pressure': 1013, 'humidity': 91, 'sea_level': 1013, 'grnd_level': 965}, 'visibility': 10000, 'wind': {'speed': 1.81, 'deg': 238}, 'clouds': {'all': 99}, 'dt': 1598646776, 'sys': {'country': 'CG', 'sunrise': 1598590714, 'sunset': 1598634452}, 'timezone': 3600, 'id': 2255304, 'name': 'Sémbé', 'cod': 200}
# Processing Record 44 of Set 1 | sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D4576F988>)
# Processing Record 45 of Set 1 | chokurdakh
# {'coord': {'lon': 147.92, 'lat': 70.63}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 39, 'feels_like': 31.98, 'temp_min': 39, 'temp_max': 39, 'pressure': 1026, 'humidity': 86, 'sea_level': 1026, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 61}, 'clouds': {'all': 100}, 'dt': 1598646696, 'sys': {'country': 'RU', 'sunrise': 1598637977, 'sunset': 1598695964}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 46 of Set 1 | pisco
# {'coord': {'lon': -76.22, 'lat': -13.7}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 65.23, 'feels_like': 61.93, 'temp_min': 64, 'temp_max': 66.2, 'pressure': 1016, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 280}, 'clouds': {'all': 20}, 'dt': 1598646776, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1598613122, 'sunset': 1598655619}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 47 of Set 1 | mount gambier
# {'coord': {'lon': 140.77, 'lat': -37.83}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 37.76, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1024, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1598646776, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1598648588, 'sunset': 1598688784}, 'timezone': 34200, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# Processing Record 48 of Set 1 | ust-ilimsk
# {'coord': {'lon': 102.66, 'lat': 58}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 53.13, 'feels_like': 52.81, 'temp_min': 53.13, 'temp_max': 53.13, 'pressure': 1013, 'humidity': 90, 'sea_level': 1013, 'grnd_level': 978}, 'visibility': 10000, 'wind': {'speed': 0.85, 'deg': 253}, 'clouds': {'all': 100}, 'dt': 1598646777, 'sys': {'country': 'RU', 'sunrise': 1598652189, 'sunset': 1598703471}, 'timezone': 28800, 'id': 2013952, 'name': "Ust'-Ilimsk", 'cod': 200}
# Processing Record 49 of Set 1 | tasiilaq
# {'coord': {'lon': -37.64, 'lat': 65.61}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 37.31, 'temp_min': 41, 'temp_max': 41, 'pressure': 1014, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 1.12, 'deg': 40}, 'clouds': {'all': 100}, 'dt': 1598646777, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1598597777, 'sunset': 1598652449}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 50 of Set 1 | flin flon
# {'coord': {'lon': -101.86, 'lat': 54.77}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 66.2, 'feels_like': 61.52, 'temp_min': 66.2, 'temp_max': 66.2, 'pressure': 1011, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 320, 'gust': 18.34}, 'clouds': {'all': 40}, 'dt': 1598646777, 'sys': {'type': 1, 'id': 782, 'country': 'CA', 'sunrise': 1598615290, 'sunset': 1598665756}, 'timezone': -18000, 'id': 5954718, 'name': 'Flin Flon', 'cod': 200}
# Processing Record 1 of Set 2 | kostino
# {'coord': {'lon': 53.27, 'lat': 58.91}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 58.1, 'feels_like': 57.54, 'temp_min': 58.1, 'temp_max': 58.1, 'pressure': 1008, 'humidity': 97, 'sea_level': 1008, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 5.08, 'deg': 133}, 'rain': {'1h': 0.56}, 'clouds': {'all': 100}, 'dt': 1598646777, 'sys': {'country': 'RU', 'sunrise': 1598577379, 'sunset': 1598629219}, 'timezone': 10800, 'id': 543939, 'name': 'Kostino', 'cod': 200}
# Processing Record 2 of Set 2 | arraial do cabo
# {'coord': {'lon': -42.03, 'lat': -22.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 74.17, 'feels_like': 72.07, 'temp_min': 73.4, 'temp_max': 75.2, 'pressure': 1017, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 70}, 'clouds': {'all': 0}, 'dt': 1598646736, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1598605324, 'sunset': 1598647009}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 3 of Set 2 | hobart
# {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 52.59, 'feels_like': 40.96, 'temp_min': 51.01, 'temp_max': 53.6, 'pressure': 1016, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 330}, 'clouds': {'all': 75}, 'dt': 1598646747, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1598647342, 'sunset': 1598686882}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 4 of Set 2 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.87}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 40.89, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1012, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 270}, 'clouds': {'all': 44}, 'dt': 1598646778, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1598652886, 'sunset': 1598693541}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 5 of Set 2 | tumbagaan
# {'coord': {'lon': 120.31, 'lat': 5.37}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81, 'feels_like': 88.09, 'temp_min': 81, 'temp_max': 81, 'pressure': 1007, 'humidity': 75, 'sea_level': 1007, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 173}, 'clouds': {'all': 78}, 'dt': 1598646778, 'sys': {'country': 'PH', 'sunrise': 1598651580, 'sunset': 1598695610}, 'timezone': 28800, 'id': 1680745, 'name': 'Tumbagaan', 'cod': 200}
# Processing Record 6 of Set 2 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 78.13, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1020, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 90, 'gust': 19.46}, 'clouds': {'all': 75}, 'dt': 1598646748, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1598723533, 'sunset': 1598765472}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 7 of Set 2 | touros
# {'coord': {'lon': -35.46, 'lat': -5.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 81.54, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1013, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 170}, 'clouds': {'all': 20}, 'dt': 1598646744, 'sys': {'type': 1, 'id': 8452, 'country': 'BR', 'sunrise': 1598602997, 'sunset': 1598646183}, 'timezone': -10800, 'id': 3386213, 'name': 'Touros', 'cod': 200}
# Processing Record 8 of Set 2 | erzin
# {'coord': {'lon': 36.2, 'lat': 36.96}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 81, 'feels_like': 90.77, 'temp_min': 81, 'temp_max': 81, 'pressure': 1006, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 26}, 'clouds': {'all': 0}, 'dt': 1598646778, 'sys': {'type': 3, 'id': 2007718, 'country': 'TR', 'sunrise': 1598583788, 'sunset': 1598631003}, 'timezone': 10800, 'id': 296852, 'name': 'Erzin', 'cod': 200}
# Processing Record 9 of Set 2 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45783808>)
# Processing Record 10 of Set 2 | puerto ayacucho
# {'coord': {'lon': -67.62, 'lat': 5.66}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 91.4, 'feels_like': 93.25, 'temp_min': 91.4, 'temp_max': 91.4, 'pressure': 1008, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 40}, 'clouds': {'all': 40}, 'dt': 1598646778, 'sys': {'type': 1, 'id': 8586, 'country': 'VE', 'sunrise': 1598610276, 'sunset': 1598654338}, 'timezone': -14400, 'id': 3629710, 'name': 'Puerto Ayacucho', 'cod': 200}
# Processing Record 11 of Set 2 | atuona
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.61, 'feels_like': 72.7, 'temp_min': 77.61, 'temp_max': 77.61, 'pressure': 1013, 'humidity': 81, 'sea_level': 1013, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 23.47, 'deg': 101}, 'rain': {'1h': 0.58}, 'clouds': {'all': 72}, 'dt': 1598646742, 'sys': {'country': 'PF', 'sunrise': 1598628031, 'sunset': 1598670853}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 12 of Set 2 | georgetown
# {'coord': {'lon': 100.34, 'lat': 5.41}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 79.25, 'feels_like': 89.2, 'temp_min': 78.01, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 88}, 'visibility': 8000, 'wind': {'speed': 1.12, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1598646760, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1598656371, 'sunset': 1598700403}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 13 of Set 2 | novokruchininskiy
# {'coord': {'lon': 113.77, 'lat': 51.78}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 52.38, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1016, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 90}, 'clouds': {'all': 40}, 'dt': 1598646779, 'sys': {'type': 1, 'id': 8890, 'country': 'RU', 'sunrise': 1598650347, 'sunset': 1598699982}, 'timezone': 32400, 'id': 2018925, 'name': 'Novokruchininskiy', 'cod': 200}
# Processing Record 14 of Set 2 | cape town
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 52.11, 'feels_like': 44.71, 'temp_min': 50, 'temp_max': 53.01, 'pressure': 1012, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1598646759, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1598591379, 'sunset': 1598631944}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 15 of Set 2 | college
# {'coord': {'lon': -147.8, 'lat': 64.86}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}, {'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 51.64, 'feels_like': 50.45, 'temp_min': 50, 'temp_max': 53.01, 'pressure': 1009, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.28, 'deg': 244}, 'clouds': {'all': 90}, 'dt': 1598646607, 'sys': {'type': 1, 'id': 7683, 'country': 'US', 'sunrise': 1598624475, 'sunset': 1598678618}, 'timezone': -28800, 'id': 5859699, 'name': 'College', 'cod': 200}
# Processing Record 16 of Set 2 | louisbourg
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45799388>)
# Processing Record 17 of Set 2 | kabansk
# {'coord': {'lon': 106.65, 'lat': 52.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 57.79, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1013, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.81, 'deg': 141}, 'clouds': {'all': 90}, 'dt': 1598646779, 'sys': {'type': 1, 'id': 8896, 'country': 'RU', 'sunrise': 1598652027, 'sunset': 1598701719}, 'timezone': 28800, 'id': 2023350, 'name': 'Kabansk', 'cod': 200}
# Processing Record 18 of Set 2 | bredasdorp
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 43.34, 'temp_min': 50, 'temp_max': 50, 'pressure': 1010, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 30}, 'clouds': {'all': 3}, 'dt': 1598646706, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1598591025, 'sunset': 1598631521}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 19 of Set 2 | puerto ayora
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 68.97, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1014, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 18.34, 'deg': 120}, 'clouds': {'all': 48}, 'dt': 1598646780, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1598615989, 'sunset': 1598659533}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 20 of Set 2 | port said
# {'coord': {'lon': 32.28, 'lat': 31.26}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 83.43, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 350}, 'clouds': {'all': 0}, 'dt': 1598646780, 'sys': {'type': 1, 'id': 2522, 'country': 'EG', 'sunrise': 1598585086, 'sunset': 1598631585}, 'timezone': 7200, 'id': 358619, 'name': 'Port Said', 'cod': 200}
# Processing Record 21 of Set 2 | grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D457998C8>)
# Processing Record 22 of Set 2 | kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.51, 'feels_like': 83.93, 'temp_min': 77, 'temp_max': 84.99, 'pressure': 1018, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 60}, 'clouds': {'all': 75}, 'dt': 1598646748, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1598631568, 'sunset': 1598677052}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 23 of Set 2 | bethel
# {'coord': {'lon': -73.41, 'lat': 41.37}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 81.41, 'temp_min': 81, 'temp_max': 84, 'pressure': 1010, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 300}, 'clouds': {'all': 1}, 'dt': 1598646620, 'sys': {'type': 1, 'id': 3888, 'country': 'US', 'sunrise': 1598609795, 'sunset': 1598657598}, 'timezone': -14400, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 24 of Set 2 | lasa
# {'coord': {'lon': 10.7, 'lat': 46.62}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 53.46, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1011, 'humidity': 100}, 'visibility': 4000, 'wind': {'speed': 2.24, 'deg': 210}, 'clouds': {'all': 90}, 'dt': 1598646743, 'sys': {'type': 1, 'id': 6813, 'country': 'IT', 'sunrise': 1598589151, 'sunset': 1598637878}, 'timezone': 7200, 'id': 3175096, 'name': 'Laas', 'cod': 200}
# Processing Record 25 of Set 2 | chodavaram
# {'coord': {'lon': 82.95, 'lat': 17.83}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 92.97, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1004, 'humidity': 94}, 'visibility': 4000, 'wind': {'speed': 5.82, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1598646780, 'sys': {'type': 1, 'id': 9255, 'country': 'IN', 'sunrise': 1598660025, 'sunset': 1598705095}, 'timezone': 19800, 'id': 1274020, 'name': 'Chodavaram', 'cod': 200}
# Processing Record 26 of Set 2 | provideniya
# {'coord': {'lon': -173.3, 'lat': 64.38}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50.92, 'feels_like': 47.59, 'temp_min': 50.92, 'temp_max': 50.92, 'pressure': 1014, 'humidity': 72, 'sea_level': 1014, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 2.77, 'deg': 81}, 'clouds': {'all': 89}, 'dt': 1598646780, 'sys': {'country': 'RU', 'sunrise': 1598717308, 'sunset': 1598770785}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 27 of Set 2 | hovd
# {'coord': {'lon': 91.64, 'lat': 48.01}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.98, 'feels_like': 49.6, 'temp_min': 51.98, 'temp_max': 51.98, 'pressure': 1015, 'humidity': 66, 'sea_level': 1015, 'grnd_level': 861}, 'visibility': 10000, 'wind': {'speed': 0.6, 'deg': 240}, 'clouds': {'all': 100}, 'dt': 1598646781, 'sys': {'country': 'MN', 'sunrise': 1598656055, 'sunset': 1598704894}, 'timezone': 25200, 'id': 1516048, 'name': 'Khovd', 'cod': 200}
# Processing Record 28 of Set 2 | kahului
# {'coord': {'lon': -156.47, 'lat': 20.89}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.35, 'feels_like': 72.68, 'temp_min': 77, 'temp_max': 89.6, 'pressure': 1016, 'humidity': 38}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 50, 'gust': 28.86}, 'clouds': {'all': 40}, 'dt': 1598646754, 'sys': {'type': 1, 'id': 7879, 'country': 'US', 'sunrise': 1598630941, 'sunset': 1598676312}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# Processing Record 29 of Set 2 | jacqueville
# {'coord': {'lon': -4.41, 'lat': 5.21}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 82.9, 'temp_min': 77, 'temp_max': 77, 'pressure': 1012, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 210}, 'clouds': {'all': 20}, 'dt': 1598646781, 'sys': {'type': 1, 'id': 1162, 'country': 'CI', 'sunrise': 1598595126, 'sunset': 1598639154}, 'timezone': 0, 'id': 2287778, 'name': 'Jacqueville', 'cod': 200}
# Processing Record 30 of Set 2 | saleaula
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45793F88>)
# Processing Record 31 of Set 2 | comodoro rivadavia
# {'coord': {'lon': -67.5, 'lat': -45.87}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 24.66, 'temp_min': 41, 'temp_max': 41, 'pressure': 1009, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 250}, 'clouds': {'all': 40}, 'dt': 1598646781, 'sys': {'type': 1, 'id': 8284, 'country': 'AR', 'sunrise': 1598612764, 'sunset': 1598651793}, 'timezone': -10800, 'id': 3860443, 'name': 'Comodoro Rivadavia', 'cod': 200}
# Processing Record 32 of Set 2 | conde
# {'coord': {'lon': -34.91, 'lat': -7.26}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 79.32, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1015, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1598646781, 'sys': {'type': 1, 'id': 8391, 'country': 'BR', 'sunrise': 1598602948, 'sunset': 1598645968}, 'timezone': -10800, 'id': 3385077, 'name': 'Conde', 'cod': 200}
# Processing Record 33 of Set 2 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.43, 'feels_like': 46.65, 'temp_min': 52.43, 'temp_max': 52.43, 'pressure': 1011, 'humidity': 57, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.53, 'deg': 111}, 'clouds': {'all': 2}, 'dt': 1598646782, 'sys': {'country': 'RU', 'sunrise': 1598648256, 'sunset': 1598707482}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 34 of Set 2 | souillac
# {'coord': {'lon': 57.52, 'lat': -20.52}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 71.6, 'feels_like': 73.35, 'temp_min': 71.6, 'temp_max': 71.6, 'pressure': 1020, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1598646755, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1598667685, 'sunset': 1598709639}, 'timezone': 14400, 'id': 933995, 'name': 'Souillac', 'cod': 200}
# Processing Record 35 of Set 2 | kazerun
# {'coord': {'lon': 51.65, 'lat': 29.62}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 79.66, 'feels_like': 77.59, 'temp_min': 79.66, 'temp_max': 79.66, 'pressure': 1005, 'humidity': 29, 'sea_level': 1005, 'grnd_level': 914}, 'visibility': 10000, 'wind': {'speed': 1.43, 'deg': 49}, 'clouds': {'all': 1}, 'dt': 1598646782, 'sys': {'country': 'IR', 'sunrise': 1598666962, 'sunset': 1598713178}, 'timezone': 16200, 'id': 128321, 'name': 'Kāzerūn', 'cod': 200}
# Processing Record 36 of Set 2 | vilhena
# {'coord': {'lon': -60.15, 'lat': -12.74}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 85.82, 'temp_min': 86, 'temp_max': 86, 'pressure': 1012, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 290}, 'rain': {'1h': 0.18}, 'clouds': {'all': 49}, 'dt': 1598646782, 'sys': {'type': 1, 'id': 8457, 'country': 'BR', 'sunrise': 1598609227, 'sunset': 1598651802}, 'timezone': -14400, 'id': 3924679, 'name': 'Vilhena', 'cod': 200}
# Processing Record 37 of Set 2 | belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45799C48>)
# Processing Record 38 of Set 2 | skegness
# {'coord': {'lon': 0.34, 'lat': 53.14}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 55.94, 'feels_like': 42.93, 'temp_min': 53.6, 'temp_max': 57, 'pressure': 1002, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 25.28, 'deg': 360, 'gust': 36.91}, 'clouds': {'all': 90}, 'dt': 1598646525, 'sys': {'type': 1, 'id': 1503, 'country': 'GB', 'sunrise': 1598590941, 'sunset': 1598641059}, 'timezone': 3600, 'id': 2637762, 'name': 'Skegness', 'cod': 200}
# Processing Record 39 of Set 2 | safaga
# {'coord': {'lon': 33.94, 'lat': 26.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 89.6, 'feels_like': 85.24, 'temp_min': 89.6, 'temp_max': 89.6, 'pressure': 1003, 'humidity': 24}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1598646782, 'sys': {'type': 1, 'id': 2513, 'country': 'EG', 'sunrise': 1598584940, 'sunset': 1598630935}, 'timezone': 7200, 'id': 358620, 'name': 'Safaga', 'cod': 200}
# Processing Record 40 of Set 2 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D45796948>)
# Processing Record 41 of Set 2 | the valley
# ...
# Processing Record 36 of Set 15 | ingham
# {'coord': {'lon': -84.38, 'lat': 42.6}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.84, 'feels_like': 83.05, 'temp_min': 78.8, 'temp_max': 82, 'pressure': 1007, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 10.07, 'deg': 224}, 'clouds': {'all': 40}, 'dt': 1598646910, 'sys': {'type': 1, 'id': 6016, 'country': 'US', 'sunrise': 1598612334, 'sunset': 1598660323}, 'timezone': -14400, 'id': 4997130, 'name': 'Ingham', 'cod': 200}
# Processing Record 37 of Set 15 | khonuu
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D467CBC48>)
# Processing Record 38 of Set 15 | ozernovskiy
# {'coord': {'lon': 156.52, 'lat': 51.5}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 50.86, 'feels_like': 47.44, 'temp_min': 50.86, 'temp_max': 50.86, 'pressure': 1007, 'humidity': 89, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.17, 'deg': 321}, 'clouds': {'all': 90}, 'dt': 1598646910, 'sys': {'country': 'RU', 'sunrise': 1598640107, 'sunset': 1598689706}, 'timezone': 43200, 'id': 2122293, 'name': 'Ozernovskiy', 'cod': 200}
# Processing Record 39 of Set 15 | pangnirtung
# {'coord': {'lon': -65.71, 'lat': 66.15}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 41.34, 'temp_min': 48.2, 'temp_max': 48.2, 'pressure': 1009, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 260}, 'clouds': {'all': 20}, 'dt': 1598646910, 'sys': {'type': 1, 'id': 968, 'country': 'CA', 'sunrise': 1598604376, 'sunset': 1598659322}, 'timezone': -14400, 'id': 6096551, 'name': 'Pangnirtung', 'cod': 200}
# Processing Record 40 of Set 15 | grand gaube
# {'coord': {'lon': 57.66, 'lat': -20.01}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.01, 'feels_like': 70.74, 'temp_min': 69.01, 'temp_max': 69.01, 'pressure': 1019, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 164, 'gust': 8.01}, 'clouds': {'all': 1}, 'dt': 1598646910, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1598667629, 'sunset': 1598709627}, 'timezone': 14400, 'id': 934479, 'name': 'Grand Gaube', 'cod': 200}
# Processing Record 41 of Set 15 | seddon
# {'coord': {'lon': 144.89, 'lat': -37.81}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 47.61, 'feels_like': 38.62, 'temp_min': 43, 'temp_max': 50, 'pressure': 1027, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 360}, 'rain': {'1h': 0.13}, 'clouds': {'all': 0}, 'dt': 1598646911, 'sys': {'type': 1, 'id': 9548, 'country': 'AU', 'sunrise': 1598647599, 'sunset': 1598687795}, 'timezone': 36000, 'id': 7281807, 'name': 'Seddon', 'cod': 200}
# Processing Record 42 of Set 15 | srikakulam
# {'coord': {'lon': 83.9, 'lat': 18.3}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 79.63, 'feels_like': 86.49, 'temp_min': 79.63, 'temp_max': 79.63, 'pressure': 1004, 'humidity': 87, 'sea_level': 1004, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 6.62, 'deg': 250}, 'clouds': {'all': 46}, 'dt': 1598646789, 'sys': {'country': 'IN', 'sunrise': 1598659776, 'sunset': 1598704888}, 'timezone': 19800, 'id': 1255647, 'name': 'Srikakulam', 'cod': 200}
# Processing Record 43 of Set 15 | constantine
# {'coord': {'lon': 6.61, 'lat': 36.37}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 87.8, 'feels_like': 79.34, 'temp_min': 87.8, 'temp_max': 87.8, 'pressure': 1011, 'humidity': 27}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 260}, 'clouds': {'all': 20}, 'dt': 1598646911, 'sys': {'type': 1, 'id': 1074, 'country': 'DZ', 'sunrise': 1598590933, 'sunset': 1598638058}, 'timezone': 3600, 'id': 2501152, 'name': 'Constantine', 'cod': 200}
# Processing Record 44 of Set 15 | gold coast
# {'coord': {'lon': 153.43, 'lat': -28}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.54, 'feels_like': 51.75, 'temp_min': 54, 'temp_max': 59, 'pressure': 1028, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 210}, 'clouds': {'all': 67}, 'dt': 1598646824, 'sys': {'type': 1, 'id': 9486, 'country': 'AU', 'sunrise': 1598645024, 'sunset': 1598686273}, 'timezone': 36000, 'id': 2165087, 'name': 'Gold Coast', 'cod': 200}
# Processing Record 45 of Set 15 | shakhtinsk
# {'coord': {'lon': 72.59, 'lat': 49.71}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 40.05, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1021, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1598646911, 'sys': {'type': 1, 'id': 8827, 'country': 'KZ', 'sunrise': 1598660464, 'sunset': 1598709627}, 'timezone': 21600, 'id': 1519327, 'name': 'Shakhtinsk', 'cod': 200}
# Processing Record 46 of Set 15 | cuamba
# {'coord': {'lon': 36.54, 'lat': -14.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.97, 'feels_like': 69.42, 'temp_min': 72.97, 'temp_max': 72.97, 'pressure': 1013, 'humidity': 34, 'sea_level': 1013, 'grnd_level': 948}, 'visibility': 10000, 'wind': {'speed': 3.4, 'deg': 75}, 'clouds': {'all': 3}, 'dt': 1598646911, 'sys': {'country': 'MZ', 'sunrise': 1598586118, 'sunset': 1598628509}, 'timezone': 7200, 'id': 1047660, 'name': 'Cuamba', 'cod': 200}
# Processing Record 47 of Set 15 | nizhniy kuranakh
# {'coord': {'lon': 125.49, 'lat': 58.84}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 43.83, 'feels_like': 38.73, 'temp_min': 43.83, 'temp_max': 43.83, 'pressure': 1022, 'humidity': 68, 'sea_level': 1022, 'grnd_level': 980}, 'visibility': 10000, 'wind': {'speed': 3.22, 'deg': 143}, 'clouds': {'all': 75}, 'dt': 1598646790, 'sys': {'country': 'RU', 'sunrise': 1598646566, 'sunset': 1598698138}, 'timezone': 32400, 'id': 2019135, 'name': 'Nizhniy Kuranakh', 'cod': 200}
# Processing Record 48 of Set 15 | jaguaruna
# {'coord': {'lon': -49.03, 'lat': -28.61}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.57, 'feels_like': 64.9, 'temp_min': 65.57, 'temp_max': 65.57, 'pressure': 1015, 'humidity': 81, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 6.73, 'deg': 55}, 'clouds': {'all': 0}, 'dt': 1598646912, 'sys': {'country': 'BR', 'sunrise': 1598607272, 'sunset': 1598648420}, 'timezone': -10800, 'id': 3460197, 'name': 'Jaguaruna', 'cod': 200}
# Processing Record 49 of Set 15 | birao
# {'coord': {'lon': 22.79, 'lat': 10.28}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.47, 'feels_like': 76.12, 'temp_min': 71.47, 'temp_max': 71.47, 'pressure': 1010, 'humidity': 91, 'sea_level': 1010, 'grnd_level': 957}, 'visibility': 10000, 'wind': {'speed': 4.16, 'deg': 237}, 'clouds': {'all': 100}, 'dt': 1598646912, 'sys': {'country': 'CF', 'sunrise': 1598588387, 'sunset': 1598632839}, 'timezone': 3600, 'id': 240210, 'name': 'Birao', 'cod': 200}
# Processing Record 50 of Set 15 | olafsvik
# {'coord': {'lon': -23.71, 'lat': 64.89}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 52.03, 'feels_like': 43.39, 'temp_min': 52.03, 'temp_max': 52.03, 'pressure': 1018, 'humidity': 86, 'sea_level': 1018, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.54, 'deg': 259}, 'clouds': {'all': 100}, 'dt': 1598646756, 'sys': {'country': 'IS', 'sunrise': 1598594621, 'sunset': 1598648920}, 'timezone': 0, 'id': 3414079, 'name': 'Olafsvik', 'cod': 200}
# Processing Record 1 of Set 16 | asyut
# {'coord': {'lon': 31.18, 'lat': 27.18}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 82.17, 'temp_min': 86, 'temp_max': 86, 'pressure': 1008, 'humidity': 42}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1598646912, 'sys': {'type': 1, 'id': 2510, 'country': 'EG', 'sunrise': 1598585578, 'sunset': 1598631621}, 'timezone': 7200, 'id': 359783, 'name': 'Assiut', 'cod': 200}
# Processing Record 2 of Set 16 | chiman
# {'coord': {'lon': 73.81, 'lat': 32.55}, 'weather': [{'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 89.24, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1003, 'humidity': 83}, 'visibility': 4000, 'wind': {'speed': 3, 'deg': 54}, 'clouds': {'all': 0}, 'dt': 1598646912, 'sys': {'type': 1, 'id': 7594, 'country': 'PK', 'sunrise': 1598661477, 'sunset': 1598708029}, 'timezone': 18000, 'id': 1179790, 'name': 'Chiman', 'cod': 200}
# Processing Record 3 of Set 16 | general salgado
# {'coord': {'lon': -50.36, 'lat': -20.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.52, 'feels_like': 78.8, 'temp_min': 83.52, 'temp_max': 83.52, 'pressure': 1011, 'humidity': 22, 'sea_level': 1011, 'grnd_level': 956}, 'visibility': 10000, 'wind': {'speed': 4.65, 'deg': 90}, 'clouds': {'all': 0}, 'dt': 1598646912, 'sys': {'country': 'BR', 'sunrise': 1598607217, 'sunset': 1598649114}, 'timezone': -10800, 'id': 3462487, 'name': 'General Salgado', 'cod': 200}
# Processing Record 4 of Set 16 | khao yoi
# {'coord': {'lon': 99.82, 'lat': 13.24}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.99, 'feels_like': 81.23, 'temp_min': 75.99, 'temp_max': 75.99, 'pressure': 1010, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 225}, 'clouds': {'all': 97}, 'dt': 1598646913, 'sys': {'type': 3, 'id': 71723, 'country': 'TH', 'sunrise': 1598656175, 'sunset': 1598700849}, 'timezone': 25200, 'id': 1152919, 'name': 'Khao Yoi', 'cod': 200}
# Processing Record 5 of Set 16 | lucea
# {'coord': {'lon': -78.17, 'lat': 18.45}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 88.75, 'feels_like': 90.39, 'temp_min': 88, 'temp_max': 89.6, 'pressure': 1013, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 20.8, 'deg': 70}, 'clouds': {'all': 20}, 'dt': 1598646913, 'sys': {'type': 1, 'id': 7107, 'country': 'JM', 'sunrise': 1598612259, 'sunset': 1598657418}, 'timezone': -18000, 'id': 3489657, 'name': 'Lucea', 'cod': 200}
# Processing Record 6 of Set 16 | nkhata bay
# {'coord': {'lon': 34.29, 'lat': -11.61}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 74.62, 'feels_like': 77.7, 'temp_min': 74.62, 'temp_max': 74.62, 'pressure': 1013, 'humidity': 62, 'sea_level': 1013, 'grnd_level': 953}, 'visibility': 10000, 'wind': {'speed': 0.85, 'deg': 293}, 'clouds': {'all': 0}, 'dt': 1598646913, 'sys': {'country': 'MW', 'sunrise': 1598586524, 'sunset': 1598629183}, 'timezone': 7200, 'id': 924732, 'name': 'Nkhata Bay', 'cod': 200}
# Processing Record 7 of Set 16 | umm jarr
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D467CF548>)
# Processing Record 8 of Set 16 | quetzaltepec
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x0000014D467CFD88>)
# Processing Record 9 of Set 16 | bandarbeyla
# {'coord': {'lon': 50.81, 'lat': 9.49}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.94, 'feels_like': 65.97, 'temp_min': 75.94, 'temp_max': 75.94, 'pressure': 1007, 'humidity': 79, 'sea_level': 1007, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 30.33, 'deg': 211}, 'clouds': {'all': 5}, 'dt': 1598646913, 'sys': {'country': 'SO', 'sunrise': 1598581696, 'sunset': 1598626083}, 'timezone': 10800, 'id': 64814, 'name': 'Bandarbeyla', 'cod': 200}
# Processing Record 10 of Set 16 | kijang
# {'coord': {'lon': 129.21, 'lat': 35.24}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 86.86, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1009, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1598646914, 'sys': {'type': 1, 'id': 8086, 'country': 'KR', 'sunrise': 1598648012, 'sunset': 1598694907}, 'timezone': 32400, 'id': 1842966, 'name': 'Gijang', 'cod': 200}
# Processing Record 11 of Set 16 | sitka
# {'coord': {'lon': -135.33, 'lat': 57.05}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 48.74, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1006, 'humidity': 87}, 'visibility': 9656, 'wind': {'speed': 12.75, 'deg': 170, 'gust': 21.92}, 'clouds': {'all': 90}, 'dt': 1598646914, 'sys': {'type': 1, 'id': 7795, 'country': 'US', 'sunrise': 1598623011, 'sunset': 1598674098}, 'timezone': -28800, 'id': 5557293, 'name': 'Sitka', 'cod': 200}
# Processing Record 12 of Set 16 | garowe
# {'coord': {'lon': 48.48, 'lat': 8.41}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 75.97, 'feels_like': 65.82, 'temp_min': 75.97, 'temp_max': 75.97, 'pressure': 1009, 'humidity': 63, 'sea_level': 1009, 'grnd_level': 957}, 'visibility': 10000, 'wind': {'speed': 25.52, 'deg': 193}, 'clouds': {'all': 50}, 'dt': 1598646914, 'sys': {'country': 'SO', 'sunrise': 1598582301, 'sunset': 1598626597}, 'timezone': 10800, 'id': 58933, 'name': 'Garoowe', 'cod': 200}
# Processing Record 13 of Set 16 | goderich
# {'coord': {'lon': -81.72, 'lat': 43.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.74, 'feels_like': 78.58, 'temp_min': 75, 'temp_max': 77, 'pressure': 1006, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 4.52, 'deg': 165}, 'clouds': {'all': 89}, 'dt': 1598646914, 'sys': {'type': 3, 'id': 2008021, 'country': 'CA', 'sunrise': 1598611602, 'sunset': 1598659779}, 'timezone': -14400, 'id': 5962442, 'name': 'Goderich', 'cod': 200}
# Processing Record 14 of Set 16 | dudinka
# {'coord': {'lon': 86.18, 'lat': 69.41}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 48.38, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1009, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 150}, 'clouds': {'all': 91}, 'dt': 1598646914, 'sys': {'type': 1, 'id': 8951, 'country': 'RU', 'sunrise': 1598653352, 'sunset': 1598710217}, 'timezone': 25200, 'id': 1507116, 'name': 'Dudinka', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)

# Create output file
output_data_file = "../weather_database/WeatherPy_Database.csv"

# export the city_data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
city_data_df.tail(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 692  General Salgado      BR -20.65  -50.36     83.52        22           0
# 693         Khao Yoi      TH  13.24   99.82     75.99        79          97
# 694            Lucea      JM  18.45  -78.17     89.60        75          20
# 695       Nkhata Bay      MW -11.61   34.29     74.62        62           0
# 696      Bandarbeyla      SO   9.49   50.81     75.94        79           5
# 697           Kijang      KR  35.24  129.21     78.80        83          75
# 698            Sitka      US  57.05 -135.33     55.40        87          90
# 699           Garowe      SO   8.41   48.48     75.97        63          50
# 700         Goderich      CA  43.75  -81.72     77.00        70          89
# 701          Dudinka      RU  69.41   86.18     51.80        81          91
#
#      Wind Speed Current Description
# 692        4.65           clear sky
# 693        3.36     overcast clouds
# 694       20.80          few clouds
# 695        0.85           clear sky
# 696       30.33           clear sky
# 697        2.24       broken clouds
# 698       12.75                mist
# 699       25.52    scattered clouds
# 700        4.52     overcast clouds
# 701        4.47     overcast clouds
