# %%
## Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
## Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)
# Add the lats and lngs into a list
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
## Calling the API and Parsing JSON Data
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through alll the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    
    # create end point url
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers an d the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count 
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Descriptions": weather_description})
        # If an error is experienced skip the city
    except:
        print("City not found, skipping...")
        pass
        
# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sciacca
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | attawapiskat
# City not found, skipping...
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | marzuq
# Processing Record 10 of Set 1 | horta
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | marawi
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | catalina
# Processing Record 18 of Set 1 | virginia beach
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | north platte
# Processing Record 21 of Set 1 | makasar
# Processing Record 22 of Set 1 | toora-khem
# Processing Record 23 of Set 1 | los llanos de aridane
# Processing Record 24 of Set 1 | vale da amoreira
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | bardiyah
# Processing Record 30 of Set 1 | ariquemes
# Processing Record 31 of Set 1 | grand river south east
# City not found, skipping...
# Processing Record 32 of Set 1 | karratha
# Processing Record 33 of Set 1 | laguna
# Processing Record 34 of Set 1 | ust-kut
# Processing Record 35 of Set 1 | mayumba
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | temaraia
# City not found, skipping...
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | shimoda
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | tres arroyos
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | tuatapere
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | selfoss
# Processing Record 49 of Set 1 | hailar
# Processing Record 50 of Set 1 | coihaique
# Processing Record 1 of Set 2 | tsiroanomandidy
# Processing Record 2 of Set 2 | crotone
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | boa vista
# Processing Record 10 of Set 2 | kulhudhuffushi
# Processing Record 11 of Set 2 | bezhta
# Processing Record 12 of Set 2 | lompoc
# Processing Record 13 of Set 2 | cairns
# Processing Record 14 of Set 2 | china
# Processing Record 15 of Set 2 | bababe
# City not found, skipping...
# Processing Record 16 of Set 2 | washim
# Processing Record 17 of Set 2 | abalak
# Processing Record 18 of Set 2 | amapa
# Processing Record 19 of Set 2 | batagay-alyta
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found, skipping...
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | tulum
# Processing Record 23 of Set 2 | barentsburg
# City not found, skipping...
# Processing Record 24 of Set 2 | rio grande
# Processing Record 25 of Set 2 | yerbogachen
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | sorland
# Processing Record 28 of Set 2 | port-gentil
# Processing Record 29 of Set 2 | belushya guba
# City not found, skipping...
# Processing Record 30 of Set 2 | garden city
# Processing Record 31 of Set 2 | altar
# Processing Record 32 of Set 2 | eldikan
# City not found, skipping...
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | grand gaube
# Processing Record 39 of Set 2 | fortuna
# Processing Record 40 of Set 2 | kirakira
# Processing Record 41 of Set 2 | nuuk
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | zhigansk
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | ust-omchug
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | ossora
# Processing Record 1 of Set 3 | bodden town
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | turukhansk
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | sabang
# Processing Record 6 of Set 3 | saint anthony
# Processing Record 7 of Set 3 | campbell river
# Processing Record 8 of Set 3 | bad mergentheim
# Processing Record 9 of Set 3 | yambio
# Processing Record 10 of Set 3 | hanzhong
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | gallup
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | empangeni
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | ambilobe
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | najran
# Processing Record 20 of Set 3 | qaqortoq
# Processing Record 21 of Set 3 | port blair
# Processing Record 22 of Set 3 | nizhneyansk
# City not found, skipping...
# Processing Record 23 of Set 3 | banat
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | gornouralskiy
# City not found, skipping...
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | tsihombe
# City not found, skipping...
# Processing Record 28 of Set 3 | tonantins
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | meyungs
# City not found, skipping...
# Processing Record 32 of Set 3 | ardakan
# Processing Record 33 of Set 3 | luxor
# Processing Record 34 of Set 3 | payakumbuh
# Processing Record 35 of Set 3 | berbera
# Processing Record 36 of Set 3 | taolanaro
# City not found, skipping...
# Processing Record 37 of Set 3 | buchanan
# Processing Record 38 of Set 3 | la ronge
# Processing Record 39 of Set 3 | beidao
# Processing Record 40 of Set 3 | baryshivka
# Processing Record 41 of Set 3 | osakarovka
# Processing Record 42 of Set 3 | lata
# Processing Record 43 of Set 3 | znamenka
# Processing Record 44 of Set 3 | flinders
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 46 of Set 3 | tena
# Processing Record 47 of Set 3 | marystown
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | bredasdorp
# Processing Record 1 of Set 4 | gadsden
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | partizanskoye
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | mumford
# Processing Record 7 of Set 4 | ixtapa
# Processing Record 8 of Set 4 | antofagasta
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | bourail
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | hovd
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | grindavik
# Processing Record 15 of Set 4 | darhan
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | kaeo
# Processing Record 19 of Set 4 | vaitupu
# City not found, skipping...
# Processing Record 20 of Set 4 | moyale
# Processing Record 21 of Set 4 | surt
# Processing Record 22 of Set 4 | galiwinku
# City not found, skipping...
# Processing Record 23 of Set 4 | deblin
# Processing Record 24 of Set 4 | coxim
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | banepa
# Processing Record 27 of Set 4 | vanavara
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | uruacu
# Processing Record 31 of Set 4 | phalaborwa
# Processing Record 32 of Set 4 | xichang
# Processing Record 33 of Set 4 | srednekolymsk
# Processing Record 34 of Set 4 | nabire
# Processing Record 35 of Set 4 | oskemen
# Processing Record 36 of Set 4 | corinto
# Processing Record 37 of Set 4 | avera
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | binga
# Processing Record 41 of Set 4 | chapleau
# Processing Record 42 of Set 4 | olafsvik
# Processing Record 43 of Set 4 | palabuhanratu
# City not found, skipping...
# Processing Record 44 of Set 4 | viedma
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | sainte-suzanne
# Processing Record 47 of Set 4 | svetlyy
# Processing Record 48 of Set 4 | westport
# Processing Record 49 of Set 4 | santa rosa
# Processing Record 50 of Set 4 | puerto ayora
# Processing Record 1 of Set 5 | akdepe
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | asfi
# Processing Record 4 of Set 5 | xining
# Processing Record 5 of Set 5 | ninotsminda
# Processing Record 6 of Set 5 | lorengau
# Processing Record 7 of Set 5 | indianola
# Processing Record 8 of Set 5 | bathsheba
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | narsaq
# Processing Record 11 of Set 5 | kapaa
# Processing Record 12 of Set 5 | boras
# Processing Record 13 of Set 5 | shieli
# Processing Record 14 of Set 5 | sweetwater
# Processing Record 15 of Set 5 | delijan
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | kuytun
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | port augusta
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | dmytrivka
# Processing Record 22 of Set 5 | mys shmidta
# City not found, skipping...
# Processing Record 23 of Set 5 | shenjiamen
# Processing Record 24 of Set 5 | barawe
# City not found, skipping...
# Processing Record 25 of Set 5 | porto belo
# Processing Record 26 of Set 5 | meiktila
# Processing Record 27 of Set 5 | baleshwar
# Processing Record 28 of Set 5 | morehead
# Processing Record 29 of Set 5 | ahipara
# Processing Record 30 of Set 5 | zachagansk
# City not found, skipping...
# Processing Record 31 of Set 5 | raga
# Processing Record 32 of Set 5 | marquette
# Processing Record 33 of Set 5 | diffa
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | sainte-maxime
# Processing Record 37 of Set 5 | khatanga
# Processing Record 38 of Set 5 | itoman
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | pimenta bueno
# Processing Record 43 of Set 5 | yoichi
# Processing Record 44 of Set 5 | hatillo
# Processing Record 45 of Set 5 | hihifo
# City not found, skipping...
# Processing Record 46 of Set 5 | beipiao
# Processing Record 47 of Set 5 | baykit
# Processing Record 48 of Set 5 | juneau
# Processing Record 49 of Set 5 | ferme-neuve
# Processing Record 50 of Set 5 | shelburne
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found, skipping...
# Processing Record 3 of Set 6 | villa carlos paz
# Processing Record 4 of Set 6 | kula
# Processing Record 5 of Set 6 | blackwater
# Processing Record 6 of Set 6 | tabou
# Processing Record 7 of Set 6 | rapid valley
# Processing Record 8 of Set 6 | arraial do cabo
# Processing Record 9 of Set 6 | ruatoria
# City not found, skipping...
# Processing Record 10 of Set 6 | jiwani
# Processing Record 11 of Set 6 | mar del plata
# Processing Record 12 of Set 6 | marcona
# City not found, skipping...
# Processing Record 13 of Set 6 | akyab
# Processing Record 14 of Set 6 | verkhoturye
# Processing Record 15 of Set 6 | umm kaddadah
# Processing Record 16 of Set 6 | taonan
# Processing Record 17 of Set 6 | timmins
# Processing Record 18 of Set 6 | zwedru
# Processing Record 19 of Set 6 | san juan
# Processing Record 20 of Set 6 | hirara
# Processing Record 21 of Set 6 | wexford
# Processing Record 22 of Set 6 | port hardy
# Processing Record 23 of Set 6 | port elizabeth
# Processing Record 24 of Set 6 | ulladulla
# Processing Record 25 of Set 6 | raduzhnyy
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | esperance
# Processing Record 28 of Set 6 | murygino
# Processing Record 29 of Set 6 | saryozek
# Processing Record 30 of Set 6 | awbari
# Processing Record 31 of Set 6 | bafq
# Processing Record 32 of Set 6 | bambous virieux
# Processing Record 33 of Set 6 | rio gallegos
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | forrest city
# Processing Record 37 of Set 6 | mont-dore
# Processing Record 38 of Set 6 | mayo
# Processing Record 39 of Set 6 | muroto
# Processing Record 40 of Set 6 | zyryanka
# Processing Record 41 of Set 6 | bana
# Processing Record 42 of Set 6 | cap malheureux
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | bali chak
# Processing Record 45 of Set 6 | faanui
# Processing Record 46 of Set 6 | canto do buriti
# Processing Record 47 of Set 6 | san ramon
# Processing Record 48 of Set 6 | moerai
# Processing Record 49 of Set 6 | jipijapa
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | malartic
# Processing Record 2 of Set 7 | kenai
# Processing Record 3 of Set 7 | yen bai
# Processing Record 4 of Set 7 | louisbourg
# City not found, skipping...
# Processing Record 5 of Set 7 | zaraza
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | bloomington
# Processing Record 8 of Set 7 | rawannawi
# City not found, skipping...
# Processing Record 9 of Set 7 | olinda
# Processing Record 10 of Set 7 | tiksi
# Processing Record 11 of Set 7 | matola
# Processing Record 12 of Set 7 | amderma
# City not found, skipping...
# Processing Record 13 of Set 7 | havre-saint-pierre
# Processing Record 14 of Set 7 | antalaha
# Processing Record 15 of Set 7 | estrela
# Processing Record 16 of Set 7 | pevek
# Processing Record 17 of Set 7 | bell ville
# Processing Record 18 of Set 7 | bose
# Processing Record 19 of Set 7 | takoradi
# Processing Record 20 of Set 7 | ancud
# Processing Record 21 of Set 7 | anadyr
# Processing Record 22 of Set 7 | hauge
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | ribeira grande
# Processing Record 25 of Set 7 | dhandhuka
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | inhambane
# Processing Record 28 of Set 7 | kota kinabalu
# Processing Record 29 of Set 7 | saint george
# Processing Record 30 of Set 7 | savyntsi
# Processing Record 31 of Set 7 | ciudad bolivar
# Processing Record 32 of Set 7 | opuwo
# Processing Record 33 of Set 7 | kahului
# Processing Record 34 of Set 7 | katherine
# Processing Record 35 of Set 7 | mansa
# Processing Record 36 of Set 7 | padang
# Processing Record 37 of Set 7 | samarinda
# Processing Record 38 of Set 7 | salalah
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | punta alta
# Processing Record 41 of Set 7 | vila franca do campo
# Processing Record 42 of Set 7 | yeroham
# Processing Record 43 of Set 7 | miles city
# Processing Record 44 of Set 7 | palmer
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | conceicao do araguaia
# Processing Record 47 of Set 7 | tallahassee
# Processing Record 48 of Set 7 | talara
# Processing Record 49 of Set 7 | mancio lima
# Processing Record 50 of Set 7 | hobyo
# Processing Record 1 of Set 8 | wawina
# Processing Record 2 of Set 8 | luderitz
# Processing Record 3 of Set 8 | burica
# City not found, skipping...
# Processing Record 4 of Set 8 | sambava
# Processing Record 5 of Set 8 | umm ruwabah
# City not found, skipping...
# Processing Record 6 of Set 8 | jardim
# Processing Record 7 of Set 8 | kaniama
# Processing Record 8 of Set 8 | vastervik
# City not found, skipping...
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | victoria point
# Processing Record 11 of Set 8 | samusu
# City not found, skipping...
# Processing Record 12 of Set 8 | chara
# Processing Record 13 of Set 8 | huarmey
# Processing Record 14 of Set 8 | sabha
# Processing Record 15 of Set 8 | zhezkazgan
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | kamenskoye
# City not found, skipping...
# Processing Record 18 of Set 8 | mecca
# Processing Record 19 of Set 8 | igarka
# Processing Record 20 of Set 8 | jiexiu
# Processing Record 21 of Set 8 | meadow lake
# Processing Record 22 of Set 8 | weihai
# Processing Record 23 of Set 8 | portland
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | dumas
# Processing Record 26 of Set 8 | kachiry
# Processing Record 27 of Set 8 | makung
# City not found, skipping...
# Processing Record 28 of Set 8 | linxia
# Processing Record 29 of Set 8 | swan hill
# Processing Record 30 of Set 8 | whyalla
# Processing Record 31 of Set 8 | emden
# Processing Record 32 of Set 8 | salinopolis
# Processing Record 33 of Set 8 | mana
# Processing Record 34 of Set 8 | diamantino
# Processing Record 35 of Set 8 | korla
# Processing Record 36 of Set 8 | talaya
# Processing Record 37 of Set 8 | hidalgo
# Processing Record 38 of Set 8 | arona
# Processing Record 39 of Set 8 | sinnamary
# Processing Record 40 of Set 8 | kawalu
# Processing Record 41 of Set 8 | tucuma
# Processing Record 42 of Set 8 | namatanai
# Processing Record 43 of Set 8 | ucar
# Processing Record 44 of Set 8 | utiroa
# City not found, skipping...
# Processing Record 45 of Set 8 | miri
# Processing Record 46 of Set 8 | fort saint james
# Processing Record 47 of Set 8 | mergui
# City not found, skipping...
# Processing Record 48 of Set 8 | newmarket
# Processing Record 49 of Set 8 | makuyuni
# Processing Record 50 of Set 8 | cherskiy
# Processing Record 1 of Set 9 | maturin
# Processing Record 2 of Set 9 | tuapse
# Processing Record 3 of Set 9 | port lincoln
# Processing Record 4 of Set 9 | kolokani
# Processing Record 5 of Set 9 | edendale
# Processing Record 6 of Set 9 | gabriel leyva solano
# Processing Record 7 of Set 9 | palu
# Processing Record 8 of Set 9 | robertsport
# Processing Record 9 of Set 9 | ghanzi
# Processing Record 10 of Set 9 | belmonte
# Processing Record 11 of Set 9 | cabo san lucas
# Processing Record 12 of Set 9 | iqaluit
# Processing Record 13 of Set 9 | krasnyy chikoy
# Processing Record 14 of Set 9 | clyde river
# Processing Record 15 of Set 9 | russell
# Processing Record 16 of Set 9 | nador
# Processing Record 17 of Set 9 | ushtobe
# Processing Record 18 of Set 9 | mulchen
# Processing Record 19 of Set 9 | cockburn harbour
# City not found, skipping...
# Processing Record 20 of Set 9 | puerto del rosario
# Processing Record 21 of Set 9 | eskasem
# City not found, skipping...
# Processing Record 22 of Set 9 | tuktoyaktuk
# Processing Record 23 of Set 9 | saint-pierre
# Processing Record 24 of Set 9 | dubrovka
# Processing Record 25 of Set 9 | yeppoon
# Processing Record 26 of Set 9 | xai-xai
# Processing Record 27 of Set 9 | hami
# Processing Record 28 of Set 9 | margate
# Processing Record 29 of Set 9 | namwala
# Processing Record 30 of Set 9 | quesnel
# Processing Record 31 of Set 9 | iki-burul
# Processing Record 32 of Set 9 | lanigan
# Processing Record 33 of Set 9 | lima
# Processing Record 34 of Set 9 | atar
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | yatou
# Processing Record 37 of Set 9 | karaul
# City not found, skipping...
# Processing Record 38 of Set 9 | kazalinsk
# City not found, skipping...
# Processing Record 39 of Set 9 | maudaha
# Processing Record 40 of Set 9 | bermejo
# Processing Record 41 of Set 9 | kijang
# Processing Record 42 of Set 9 | mutsamudu
# City not found, skipping...
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | alacranes
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | mao
# Processing Record 47 of Set 9 | churapcha
# Processing Record 48 of Set 9 | acarau
# Processing Record 49 of Set 9 | cabinda
# Processing Record 50 of Set 9 | kloulklubed
# Processing Record 1 of Set 10 | chicama
# Processing Record 2 of Set 10 | tezu
# Processing Record 3 of Set 10 | presidencia roque saenz pena
# Processing Record 4 of Set 10 | jamame
# Processing Record 5 of Set 10 | shakawe
# Processing Record 6 of Set 10 | lebane
# Processing Record 7 of Set 10 | chino valley
# Processing Record 8 of Set 10 | sovetskaya gavan
# Processing Record 9 of Set 10 | peterhead
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | omsukchan
# Processing Record 12 of Set 10 | rabo de peixe
# Processing Record 13 of Set 10 | merrill
# Processing Record 14 of Set 10 | asau
# Processing Record 15 of Set 10 | lysyanka
# Processing Record 16 of Set 10 | sitka
# Processing Record 17 of Set 10 | predivinsk
# Processing Record 18 of Set 10 | northam
# Processing Record 19 of Set 10 | chiredzi
# Processing Record 20 of Set 10 | egvekinot
# Processing Record 21 of Set 10 | vrnograc
# Processing Record 22 of Set 10 | komarikhinskiy
# Processing Record 23 of Set 10 | purpe
# Processing Record 24 of Set 10 | pangnirtung
# Processing Record 25 of Set 10 | chulman
# Processing Record 26 of Set 10 | port macquarie
# Processing Record 27 of Set 10 | samarai
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | kurilsk
# Processing Record 30 of Set 10 | viligili
# City not found, skipping...
# Processing Record 31 of Set 10 | along
# Processing Record 32 of Set 10 | chokwe
# Processing Record 33 of Set 10 | barcelos
# Processing Record 34 of Set 10 | sechura
# Processing Record 35 of Set 10 | zilair
# Processing Record 36 of Set 10 | fomboni
# Processing Record 37 of Set 10 | ust-kuyga
# Processing Record 38 of Set 10 | senneterre
# Processing Record 39 of Set 10 | mustasaari
# Processing Record 40 of Set 10 | strezhevoy
# Processing Record 41 of Set 10 | kargil
# Processing Record 42 of Set 10 | walvis bay
# Processing Record 43 of Set 10 | goderich
# Processing Record 44 of Set 10 | tarlisua
# City not found, skipping...
# Processing Record 45 of Set 10 | clinton
# Processing Record 46 of Set 10 | balkanabat
# Processing Record 47 of Set 10 | aborlan
# Processing Record 48 of Set 10 | antanifotsy
# Processing Record 49 of Set 10 | powell river
# Processing Record 50 of Set 10 | sakhnin
# Processing Record 1 of Set 11 | maldonado
# Processing Record 2 of Set 11 | paciran
# Processing Record 3 of Set 11 | guerrero
# Processing Record 4 of Set 11 | iida
# Processing Record 5 of Set 11 | girne
# Processing Record 6 of Set 11 | tiznit
# Processing Record 7 of Set 11 | ratne
# Processing Record 8 of Set 11 | mangrol
# Processing Record 9 of Set 11 | pontarlier
# Processing Record 10 of Set 11 | kushiro
# Processing Record 11 of Set 11 | deputatskiy
# Processing Record 12 of Set 11 | bitung
# Processing Record 13 of Set 11 | pudozh
# Processing Record 14 of Set 11 | canutama
# Processing Record 15 of Set 11 | aquiraz
# Processing Record 16 of Set 11 | saint-georges
# Processing Record 17 of Set 11 | inuvik
# Processing Record 18 of Set 11 | mahibadhoo
# Processing Record 19 of Set 11 | kamenka
# Processing Record 20 of Set 11 | tongling
# Processing Record 21 of Set 11 | zamora
# Processing Record 22 of Set 11 | kavieng
# Processing Record 23 of Set 11 | nueva guinea
# Processing Record 24 of Set 11 | udachnyy
# Processing Record 25 of Set 11 | hasaki
# Processing Record 26 of Set 11 | richards bay
# Processing Record 27 of Set 11 | ola
# Processing Record 28 of Set 11 | merauke
# Processing Record 29 of Set 11 | manzhouli
# Processing Record 30 of Set 11 | avesta
# Processing Record 31 of Set 11 | kieta
# Processing Record 32 of Set 11 | bogorodskoye
# Processing Record 33 of Set 11 | tarare
# Processing Record 34 of Set 11 | qasigiannguit
# Processing Record 35 of Set 11 | bonavista
# Processing Record 36 of Set 11 | dunedin
# Processing Record 37 of Set 11 | pingzhuang
# Processing Record 38 of Set 11 | haines junction
# Processing Record 39 of Set 11 | san borja
# Processing Record 40 of Set 11 | sangueya
# Processing Record 41 of Set 11 | kruisfontein
# Processing Record 42 of Set 11 | plavinas
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | sri aman
# Processing Record 45 of Set 11 | oboyan
# Processing Record 46 of Set 11 | odweyne
# Processing Record 47 of Set 11 | tortoli
# Processing Record 48 of Set 11 | birin
# Processing Record 49 of Set 11 | visby
# Processing Record 50 of Set 11 | yaguajay
# Processing Record 1 of Set 12 | catamarca
# Processing Record 2 of Set 12 | kutum
# Processing Record 3 of Set 12 | carutapera
# Processing Record 4 of Set 12 | vao
# Processing Record 5 of Set 12 | roald
# Processing Record 6 of Set 12 | khawhai
# Processing Record 7 of Set 12 | whitehorse
# Processing Record 8 of Set 12 | maksatikha
# Processing Record 9 of Set 12 | clifton
# Processing Record 10 of Set 12 | hualmay
# Processing Record 11 of Set 12 | kaduy
# Processing Record 12 of Set 12 | ketchikan
# Processing Record 13 of Set 12 | sukhumi
# Processing Record 14 of Set 12 | belyy yar
# Processing Record 15 of Set 12 | solnechnyy
# Processing Record 16 of Set 12 | raudeberg
# Processing Record 17 of Set 12 | yar-sale
# Processing Record 18 of Set 12 | mazamari
# Processing Record 19 of Set 12 | tilichiki
# Processing Record 20 of Set 12 | bilma
# Processing Record 21 of Set 12 | saravena
# Processing Record 22 of Set 12 | yumen
# Processing Record 23 of Set 12 | pleshanovo
# Processing Record 24 of Set 12 | phan thiet
# Processing Record 25 of Set 12 | uitenhage
# Processing Record 26 of Set 12 | atbasar
# Processing Record 27 of Set 12 | san javier
# Processing Record 28 of Set 12 | la presa
# Processing Record 29 of Set 12 | severodvinsk
# Processing Record 30 of Set 12 | mikhaylovskoye
# Processing Record 31 of Set 12 | martapura
# Processing Record 32 of Set 12 | nouadhibou
# Processing Record 33 of Set 12 | svetlogorsk
# Processing Record 34 of Set 12 | ayan
# Processing Record 35 of Set 12 | phek
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | tiarei
# Processing Record 38 of Set 12 | iturbe
# Processing Record 39 of Set 12 | maniitsoq
# Processing Record 40 of Set 12 | gorontalo
# Processing Record 41 of Set 12 | soyo
# Processing Record 42 of Set 12 | gat
# Processing Record 43 of Set 12 | berlevag
# Processing Record 44 of Set 12 | labuhan
# Processing Record 45 of Set 12 | bilibino
# Processing Record 46 of Set 12 | harper
# Processing Record 47 of Set 12 | lakshmipur
# Processing Record 48 of Set 12 | barra do garcas
# Processing Record 49 of Set 12 | broome
# Processing Record 50 of Set 12 | gizo
# Processing Record 1 of Set 13 | shetpe
# Processing Record 2 of Set 13 | phan rang
# City not found, skipping...
# Processing Record 3 of Set 13 | phonhong
# Processing Record 4 of Set 13 | kabare
# Processing Record 5 of Set 13 | biltine
# Processing Record 6 of Set 13 | kalisz
# Processing Record 7 of Set 13 | salvador
# Processing Record 8 of Set 13 | el alto
# Processing Record 9 of Set 13 | atherton
# Processing Record 10 of Set 13 | changying
# Processing Record 11 of Set 13 | khashuri
# Processing Record 12 of Set 13 | puerto penasco
# Processing Record 13 of Set 13 | sampit
# Processing Record 14 of Set 13 | sao francisco
# Processing Record 15 of Set 13 | umm lajj
# Processing Record 16 of Set 13 | khon kaen
# Processing Record 17 of Set 13 | tasbuget
# City not found, skipping...
# Processing Record 18 of Set 13 | basco
# Processing Record 19 of Set 13 | olden
# Processing Record 20 of Set 13 | namibe
# Processing Record 21 of Set 13 | santa cruz
# Processing Record 22 of Set 13 | leiyang
# Processing Record 23 of Set 13 | arkhangelsk
# Processing Record 24 of Set 13 | bosaso
# Processing Record 25 of Set 13 | kavali
# Processing Record 26 of Set 13 | yarada
# Processing Record 27 of Set 13 | zinder
# Processing Record 28 of Set 13 | kalmar
# Processing Record 29 of Set 13 | tommot
# Processing Record 30 of Set 13 | chilliwack
# Processing Record 31 of Set 13 | luang prabang
# Processing Record 32 of Set 13 | jeremie
# Processing Record 33 of Set 13 | sarangani
# Processing Record 34 of Set 13 | hit
# Processing Record 35 of Set 13 | vihari
# Processing Record 36 of Set 13 | jiangyou
# Processing Record 37 of Set 13 | kinel-cherkassy
# Processing Record 38 of Set 13 | muros
# Processing Record 39 of Set 13 | mehamn
# Processing Record 40 of Set 13 | cabedelo
# Processing Record 41 of Set 13 | san cristobal
# Processing Record 42 of Set 13 | charters towers
# Processing Record 43 of Set 13 | palauig
# Processing Record 44 of Set 13 | kos
# Processing Record 45 of Set 13 | smithers
# Processing Record 46 of Set 13 | high level
# Processing Record 47 of Set 13 | maua
# Processing Record 48 of Set 13 | toliary
# City not found, skipping...
# Processing Record 49 of Set 13 | mutoko
# Processing Record 50 of Set 13 | batemans bay
# Processing Record 1 of Set 14 | tomatlan
# Processing Record 2 of Set 14 | correntina
# Processing Record 3 of Set 14 | huandacareo
# Processing Record 4 of Set 14 | varkkallai
# Processing Record 5 of Set 14 | alcazar de san juan
# Processing Record 6 of Set 14 | harsewinkel
# Processing Record 7 of Set 14 | normandin
# Processing Record 8 of Set 14 | severomuysk
# Processing Record 9 of Set 14 | sokolow podlaski
# Processing Record 10 of Set 14 | menongue
# Processing Record 11 of Set 14 | taos
# Processing Record 12 of Set 14 | ambagarh chauki
# Processing Record 13 of Set 14 | baghdad
# Processing Record 14 of Set 14 | labuan
# Processing Record 15 of Set 14 | sitio novo do tocantins
# Processing Record 16 of Set 14 | qeshm
# Processing Record 17 of Set 14 | luancheng
# Processing Record 18 of Set 14 | acapulco
# Processing Record 19 of Set 14 | veraval
# Processing Record 20 of Set 14 | poopo
# Processing Record 21 of Set 14 | semirom
# Processing Record 22 of Set 14 | ballsh
# Processing Record 23 of Set 14 | oksovskiy
# Processing Record 24 of Set 14 | dzhusaly
# City not found, skipping...
# Processing Record 25 of Set 14 | angoche
# Processing Record 26 of Set 14 | kentau
# Processing Record 27 of Set 14 | murray bridge
# Processing Record 28 of Set 14 | minsk
# Processing Record 29 of Set 14 | warqla
# City not found, skipping...
# Processing Record 30 of Set 14 | praia da vitoria
# Processing Record 31 of Set 14 | neya
# Processing Record 32 of Set 14 | barnstaple
# Processing Record 33 of Set 14 | devils lake
# Processing Record 34 of Set 14 | port shepstone
# Processing Record 35 of Set 14 | channel-port aux basques
# Processing Record 36 of Set 14 | lofthus
# Processing Record 37 of Set 14 | siniscola
# Processing Record 38 of Set 14 | seymchan
# Processing Record 39 of Set 14 | yunjinghong
# City not found, skipping...
# Processing Record 40 of Set 14 | sorong
# Processing Record 41 of Set 14 | mozarlandia
# Processing Record 42 of Set 14 | rungata
# City not found, skipping...
# Processing Record 43 of Set 14 | yibin
# Processing Record 44 of Set 14 | madawaska
# Processing Record 45 of Set 14 | dukat
# Processing Record 46 of Set 14 | posevnaya
# Processing Record 47 of Set 14 | bolungarvik
# City not found, skipping...
# Processing Record 48 of Set 14 | saleaula
# City not found, skipping...
# Processing Record 49 of Set 14 | nantucket
# Processing Record 50 of Set 14 | paamiut
# Processing Record 1 of Set 15 | alofi
# Processing Record 2 of Set 15 | gejiu
# Processing Record 3 of Set 15 | kazachinskoye
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | sinkat
# City not found, skipping...
# Processing Record 6 of Set 15 | moindou
# Processing Record 7 of Set 15 | amboasary
# Processing Record 8 of Set 15 | kupang
# Processing Record 9 of Set 15 | tsaratanana
# Processing Record 10 of Set 15 | patur
# Processing Record 11 of Set 15 | culleredo
# Processing Record 12 of Set 15 | padre bernardo
# Processing Record 13 of Set 15 | tornio
# Processing Record 14 of Set 15 | great falls
# Processing Record 15 of Set 15 | nizhneangarsk
# Processing Record 16 of Set 15 | san andres
# Processing Record 17 of Set 15 | isiro
# Processing Record 18 of Set 15 | iskateley
# Processing Record 19 of Set 15 | haimen
# Processing Record 20 of Set 15 | ha giang
# Processing Record 21 of Set 15 | daru
# Processing Record 22 of Set 15 | hervey bay
# Processing Record 23 of Set 15 | fukuma
# Processing Record 24 of Set 15 | aksarka
# Processing Record 25 of Set 15 | tingrela
# City not found, skipping...
# Processing Record 26 of Set 15 | tahoua
# Processing Record 27 of Set 15 | coruripe
# Processing Record 28 of Set 15 | wajima
# Processing Record 29 of Set 15 | tarko-sale
# Processing Record 30 of Set 15 | dingle
# Processing Record 31 of Set 15 | ostersund
# Processing Record 32 of Set 15 | galveston
# Processing Record 33 of Set 15 | gladstone
# Processing Record 34 of Set 15 | viamao
# Processing Record 35 of Set 15 | port moresby
# Processing Record 36 of Set 15 | rasova
# Processing Record 37 of Set 15 | fairbanks
# Processing Record 38 of Set 15 | kamyshin
# Processing Record 39 of Set 15 | kolosovka
# Processing Record 40 of Set 15 | poltavka
# Processing Record 41 of Set 15 | gasa
# Processing Record 42 of Set 15 | urzhum
# Processing Record 43 of Set 15 | songea
# Processing Record 44 of Set 15 | komsomolskiy
# Processing Record 45 of Set 15 | cayenne
# Processing Record 46 of Set 15 | batticaloa
# Processing Record 47 of Set 15 | ramganj
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)

# Create output file
output_data_file = "../weather_database/WeatherPy_Database.csv"

# export the city_data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
